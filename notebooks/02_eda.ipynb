# %% [markdown]
# Dans cette partie nous allons repartir d'une base propre et comprendre nous données
#
# 1 - Import et chargement des tables <br/>
# 2 - Vue sur les tables
# 3 - Analyse des colonnes (Comprendre les vaiables)
# 4 - Taux de remplissage par tables et par colonne
# 5 - Unicité des identifiants
# 6 - Analyse des doublons
# 7 - Premières relations entre taables
# 8 - Synthèse de l'EDA
